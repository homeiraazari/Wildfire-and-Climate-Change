# %%
import pandas as pd
import sqlite3
import datetime

# %%
con = sqlite3.connect("C:/Users/mrunm/Documents/GitHub/Wildfire-and-Climate-Change/data/wildfires.sqlite")

# %%
pd.set_option('display.max_columns', 500)

# %%
fire = pd.read_sql_query("SELECT * from fires", con)
fire.head()
# Out:
#    OBJECTID  FOD_ID      FPA_ID SOURCE_SYSTEM_TYPE SOURCE_SYSTEM  \
# 0         1       1  FS-1418826                FED   FS-FIRESTAT
# 1         2       2  FS-1418827                FED   FS-FIRESTAT
# 2         3       3  FS-1418835                FED   FS-FIRESTAT
# 3         4       4  FS-1418845                FED   FS-FIRESTAT
# 4         5       5  FS-1418847                FED   FS-FIRESTAT
#
#   NWCG_REPORTING_AGENCY NWCG_REPORTING_UNIT_ID  NWCG_REPORTING_UNIT_NAME  \
# 0                    FS                USCAPNF    Plumas National Forest
# 1                    FS                USCAENF  Eldorado National Forest
# 2                    FS                USCAENF  Eldorado National Forest
# 3                    FS                USCAENF  Eldorado National Forest
# 4                    FS                USCAENF  Eldorado National Forest
#
#   SOURCE_REPORTING_UNIT SOURCE_REPORTING_UNIT_NAME LOCAL_FIRE_REPORT_ID  \
# ...

# %%
fire.describe()
# Out:
#            OBJECTID        FOD_ID     FIRE_YEAR  DISCOVERY_DATE  \
# count  1.880465e+06  1.880465e+06  1.880465e+06    1.880465e+06
# mean   9.402330e+05  5.484020e+07  2.003710e+03    2.453064e+06
# std    5.428436e+05  1.011963e+08  6.663099e+00    2.434573e+03
# min    1.000000e+00  1.000000e+00  1.992000e+03    2.448622e+06
# 25%    4.701170e+05  5.055000e+05  1.998000e+03    2.451084e+06
# 50%    9.402330e+05  1.067761e+06  2.004000e+03    2.453178e+06
# 75%    1.410349e+06  1.910639e+07  2.009000e+03    2.455036e+06
# max    1.880465e+06  3.003484e+08  2.015000e+03    2.457388e+06
#
#        DISCOVERY_DOY  STAT_CAUSE_CODE     CONT_DATE       CONT_DOY  \
# count   1.880465e+06     1.880465e+06  9.889340e+05  988934.000000
# mean    1.647191e+02     5.979037e+00  2.453238e+06     172.656766
# std     9.003891e+01     3.483860e+00  2.687548e+03      84.320348
# min     1.000000e+00     1.000000e+00  2.448622e+06       1.000000
# ...

# %%
fire.shape
# Out:
# (1880465, 39)

# %%
wildfires_cleaned=fire[["SOURCE_REPORTING_UNIT_NAME","FIRE_NAME","FIRE_YEAR","DISCOVERY_DATE","DISCOVERY_DOY","STAT_CAUSE_DESCR","CONT_DATE","CONT_DOY","FIRE_SIZE","FIRE_SIZE_CLASS","LATITUDE","LONGITUDE","STATE","COUNTY","Shape"]]
wildfires_cleaned.head()
# Out:
#   SOURCE_REPORTING_UNIT_NAME FIRE_NAME  FIRE_YEAR  DISCOVERY_DATE  \
# 0     Plumas National Forest  FOUNTAIN       2005       2453403.5
# 1   Eldorado National Forest    PIGEON       2004       2453137.5
# 2   Eldorado National Forest     SLACK       2004       2453156.5
# 3   Eldorado National Forest      DEER       2004       2453184.5
# 4   Eldorado National Forest  STEVENOT       2004       2453184.5
#
#    DISCOVERY_DOY STAT_CAUSE_DESCR  CONT_DATE  CONT_DOY  FIRE_SIZE  \
# 0             33    Miscellaneous  2453403.5      33.0       0.10
# 1            133        Lightning  2453137.5     133.0       0.25
# 2            152   Debris Burning  2453156.5     152.0       0.10
# 3            180        Lightning  2453189.5     185.0       0.10
# 4            180        Lightning  2453189.5     185.0       0.10
#
#   FIRE_SIZE_CLASS   LATITUDE   LONGITUDE STATE COUNTY  \
# 0               A  40.036944 -121.005833    CA     63
# 1               A  38.933056 -120.404444    CA     61
# ...

# %%
fires = wildfires_cleaned.rename(columns={"SOURCE_REPORTING_UNIT_NAME":"UNIT_NAME", "STAT_CAUSE_DESCR":"CAUSE_DESCR","FIRE_SIZE_CLASS":"FIRE_CLASS"})
fires.head()
# Out:
#                   UNIT_NAME FIRE_NAME  FIRE_YEAR  DISCOVERY_DATE  \
# 0    Plumas National Forest  FOUNTAIN       2005       2453403.5
# 1  Eldorado National Forest    PIGEON       2004       2453137.5
# 2  Eldorado National Forest     SLACK       2004       2453156.5
# 3  Eldorado National Forest      DEER       2004       2453184.5
# 4  Eldorado National Forest  STEVENOT       2004       2453184.5
#
#    DISCOVERY_DOY     CAUSE_DESCR  CONT_DATE  CONT_DOY  FIRE_SIZE FIRE_CLASS  \
# 0             33   Miscellaneous  2453403.5      33.0       0.10          A
# 1            133       Lightning  2453137.5     133.0       0.25          A
# 2            152  Debris Burning  2453156.5     152.0       0.10          A
# 3            180       Lightning  2453189.5     185.0       0.10          A
# 4            180       Lightning  2453189.5     185.0       0.10          A
#
#     LATITUDE   LONGITUDE STATE COUNTY  \
# 0  40.036944 -121.005833    CA     63
# ...

# %%
fires.shape
# Out:
# (1880465, 15)

# %%
print(fires.dtypes)
# Out:
# UNIT_NAME          object
# FIRE_NAME          object
# FIRE_YEAR           int64
# DISCOVERY_DATE    float64
# DISCOVERY_DOY       int64
# CAUSE_DESCR        object
# CONT_DATE         float64
# CONT_DOY          float64
# FIRE_SIZE         float64
# FIRE_CLASS         object
# LATITUDE          float64
# LONGITUDE         float64
# STATE              object
# COUNTY             object
# Shape              object
# dtype: object

# %%
#Create a new function:
def num_missing(x):
    return sum(x.isnull())

#Applying per column:
print("Missing values per column:")
## Check how many are missing by column, and then check which ones have any missing values
print(fires.apply(num_missing, axis=0).where(lambda x : x != 0).dropna().head(20)) 
#axis=0 defines that function is to be applied on each column
# Out:
# Missing values per column:
# FIRE_NAME    957189.0
# CONT_DATE    891531.0
# CONT_DOY     891531.0
# COUNTY       678148.0
# dtype: float64

# %%
#remove FIRE_NAME because it is not that important to name a fire and many obs are missing!
del fires ["FIRE_NAME"]

# %%
fires.head()
# Out:
#                   UNIT_NAME  FIRE_YEAR  DISCOVERY_DATE  DISCOVERY_DOY  \
# 0    Plumas National Forest       2005       2453403.5             33
# 1  Eldorado National Forest       2004       2453137.5            133
# 2  Eldorado National Forest       2004       2453156.5            152
# 3  Eldorado National Forest       2004       2453184.5            180
# 4  Eldorado National Forest       2004       2453184.5            180
#
#       CAUSE_DESCR  CONT_DATE  CONT_DOY  FIRE_SIZE FIRE_CLASS   LATITUDE  \
# 0   Miscellaneous  2453403.5      33.0       0.10          A  40.036944
# 1       Lightning  2453137.5     133.0       0.25          A  38.933056
# 2  Debris Burning  2453156.5     152.0       0.10          A  38.984167
# 3       Lightning  2453189.5     185.0       0.10          A  38.559167
# 4       Lightning  2453189.5     185.0       0.10          A  38.559167
#
#     LONGITUDE STATE COUNTY                                              Shape
# ...

# %%
print(fires.apply(num_missing, axis=0).where(lambda x : x != 0).dropna().head(20))
# Out:
# CONT_DATE    891531.0
# CONT_DOY     891531.0
# COUNTY       678148.0
# dtype: float64

# %%
#Julian Calendar conversion
fires['DISC_DATE'] = pd.to_datetime(fires['DISCOVERY_DATE'] - pd.Timestamp(0).to_julian_date(), unit='D')
fires.head()
# Out:
#                   UNIT_NAME  FIRE_YEAR  DISCOVERY_DATE  DISCOVERY_DOY  \
# 0    Plumas National Forest       2005       2453403.5             33
# 1  Eldorado National Forest       2004       2453137.5            133
# 2  Eldorado National Forest       2004       2453156.5            152
# 3  Eldorado National Forest       2004       2453184.5            180
# 4  Eldorado National Forest       2004       2453184.5            180
#
#       CAUSE_DESCR  CONT_DATE  CONT_DOY  FIRE_SIZE FIRE_CLASS   LATITUDE  \
# 0   Miscellaneous  2453403.5      33.0       0.10          A  40.036944
# 1       Lightning  2453137.5     133.0       0.25          A  38.933056
# 2  Debris Burning  2453156.5     152.0       0.10          A  38.984167
# 3       Lightning  2453189.5     185.0       0.10          A  38.559167
# 4       Lightning  2453189.5     185.0       0.10          A  38.559167
#
#     LONGITUDE STATE COUNTY                                              Shape  \
# ...

# %%
fires['CONTAIN_DATE'] = pd.to_datetime(fires['CONT_DATE'] - pd.Timestamp(0).to_julian_date(), unit='D')
fires.head()
# Out:
#                   UNIT_NAME  FIRE_YEAR  DISCOVERY_DATE  DISCOVERY_DOY  \
# 0    Plumas National Forest       2005       2453403.5             33
# 1  Eldorado National Forest       2004       2453137.5            133
# 2  Eldorado National Forest       2004       2453156.5            152
# 3  Eldorado National Forest       2004       2453184.5            180
# 4  Eldorado National Forest       2004       2453184.5            180
#
#       CAUSE_DESCR  CONT_DATE  CONT_DOY  FIRE_SIZE FIRE_CLASS   LATITUDE  \
# 0   Miscellaneous  2453403.5      33.0       0.10          A  40.036944
# 1       Lightning  2453137.5     133.0       0.25          A  38.933056
# 2  Debris Burning  2453156.5     152.0       0.10          A  38.984167
# 3       Lightning  2453189.5     185.0       0.10          A  38.559167
# 4       Lightning  2453189.5     185.0       0.10          A  38.559167
#
#     LONGITUDE STATE COUNTY                                              Shape  \
# ...

# %%
del fires ["DISCOVERY_DATE"]
del fires ["CONT_DATE"]

# %%
#Deleted the Julian calendar columns for Discovery date and Contaned date which were converted to normal datetime format in DISC_DATE and CONTAIN_DATE
fires.head()
# Out:
#                   UNIT_NAME  FIRE_YEAR  DISCOVERY_DOY     CAUSE_DESCR  \
# 0    Plumas National Forest       2005             33   Miscellaneous
# 1  Eldorado National Forest       2004            133       Lightning
# 2  Eldorado National Forest       2004            152  Debris Burning
# 3  Eldorado National Forest       2004            180       Lightning
# 4  Eldorado National Forest       2004            180       Lightning
#
#    CONT_DOY  FIRE_SIZE FIRE_CLASS   LATITUDE   LONGITUDE STATE COUNTY  \
# 0      33.0       0.10          A  40.036944 -121.005833    CA     63
# 1     133.0       0.25          A  38.933056 -120.404444    CA     61
# 2     152.0       0.10          A  38.984167 -120.735556    CA     17
# 3     185.0       0.10          A  38.559167 -119.913333    CA      3
# 4     185.0       0.10          A  38.559167 -119.933056    CA      3
#
#                                                Shape  DISC_DATE CONTAIN_DATE
# ...

# %%
#Missing values
#deleting the COUNTY column because of 37.7% missing values
del fires["COUNTY"]

# %%
print(fires.dtypes)
# Out:
# UNIT_NAME                object
# FIRE_YEAR                 int64
# DISCOVERY_DOY             int64
# CAUSE_DESCR              object
# CONT_DOY                float64
# FIRE_SIZE               float64
# FIRE_CLASS               object
# LATITUDE                float64
# LONGITUDE               float64
# STATE                    object
# Shape                    object
# DISC_DATE        datetime64[ns]
# CONTAIN_DATE     datetime64[ns]
# dtype: object

# %%
fires.to_sql('wildfirecleaned', con, if_exists='replace', index=False)
pd.read_sql('select * from wildfirecleaned', con)
# Out:
#                                   UNIT_NAME  FIRE_YEAR  DISCOVERY_DOY  \
# 0                    Plumas National Forest       2005             33
# 1                  Eldorado National Forest       2004            133
# 2                  Eldorado National Forest       2004            152
# 3                  Eldorado National Forest       2004            180
# 4                  Eldorado National Forest       2004            180
# 5                  Eldorado National Forest       2004            182
# 6                  Eldorado National Forest       2004            183
# 7            Shasta-Trinity National Forest       2005             67
# 8            Shasta-Trinity National Forest       2005             74
# 9                  Eldorado National Forest       2004            183
# 10                 Eldorado National Forest       2004            184
# 11                 Eldorado National Forest       2004            184
# ...
